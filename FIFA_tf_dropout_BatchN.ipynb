# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %%
###-----------------
### Import Libraries
###-----------------

import os
import sys
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from time import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

#from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix
# Out:
# WARNING:tensorflow:From D:\Anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
##from utils.helper import fn_plot_torch_hist, fn_plot_confusion_matrix is not working.
##directly copied the above functions from helper.py
def fn_plot_tf_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)
    
    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth 
        y_pred : Predictions
        labels : dictonary 
                  {0: 'Goal Keeper', 
                  1: 'Defender', 
                  2: 'Mid-Fielder', 
                  3: 'Forward'}
    
    '''
    
    cm  = confusion_matrix(y_true, y_pred)
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels.values())
    
    fig, ax = plt.subplots(figsize = (6,6))
    
    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
    # Disable the grid
    ax.grid(False)

    plt.show();

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../../input' # location where input data is stored
outDir = '../output' # location to store outputs
modelDir = '../models' # location of the images
subDir = 'fifa_2019'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well


EPOCHS = 101 # number of epochs
ALPHA = 0.001 # learning rate

BATCH_SIZE = 256
REG_LAMBDA=0.001

TEST_SIZE = 0.2

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (15,15),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
print(fn_plot_tf_hist.__doc__)  ##used to access comments from a python file
# Out:
#     Args:
#         hist_df: a dataframe with following ccolumns
#             column 0: loss
#             column 1: accuracy
#             column 2: val_loss
#             column 3: val_accuracy
#             While plotting columns are accessed by index
#             so that even if the column names are different it will not throw exceptions.

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv('fifa_2019.csv')
data_df.shape
# Out:
# (18207, 89)

# %%
# removing rows with position = null
data_df = data_df[data_df["Position"].notnull()]
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ['Position', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

data_df = data_df[rel_cols]
data_df.head()
# Out:
#   Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0       RF       95.0             70.0          90.0     86.0       97.0
# 1       ST       94.0             89.0          81.0     87.0       88.0
# 2       LW       87.0             62.0          84.0     84.0       96.0
# 3       GK       13.0             21.0          50.0     13.0       18.0
# 4      RCM       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
# Are there NaNs Still?

data_df.isna().sum()
# Out:
# Position           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# dtype: int64

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
class_labels = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

# %%
y = data_df["Position"]

X = data_df.drop("Position", axis = 1).to_numpy()

# %%
#  Split the data in training and test sets to measure performance of the model.
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=TEST_SIZE,
                                                    stratify=y,
                                                    random_state=RANDOM_STATE )

print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (14517, 33) (14517,) (3630, 33) (3630,)

# %%
sc  = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (14517, 33)

# %%
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()

# %%
#33 -> 23 -> 12 -> 4-> 4

# %%
k_init= tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)
#k_reg=tf.keras.regularizers.L2(l2=REG_LAMBDA)
k_reg=None

#Dropout Rates
dor1=0.05
dor2=0.10
dor3=0.20
dor4=0.20

#input layer
model= tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape = (33,)),
    
    #Set 1
    tf.keras.layers.Dense(33, #activation='relu',
                          kernel_initializer=k_init,
                          kernel_regularizer=k_reg),
    #BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    #DO Layer
    #tf.keras.layers.Dropout(dor1),
    #Set 2
     tf.keras.layers.Dense(23, #activation='relu',
                           kernel_initializer=k_init,
                           kernel_regularizer=k_reg),
    #BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    #DO Layer
    #tf.keras.layers.Dropout(dor2),
    #Set 3 
    tf.keras.layers.Dense(12,# activation='relu',
                           kernel_initializer=k_init,
                           kernel_regularizer=k_reg),
    #BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    #DO Layer
    #tf.keras.layers.Dropout(dor3),
    #Set 4 
    tf.keras.layers.Dense(4,# activation='relu',
                           kernel_initializer=k_init,
                           kernel_regularizer=k_reg),
    #BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    #DO Layer
    #tf.keras.layers.Dropout(dor4),
    
    #Output Layer
     tf.keras.layers.Dense(4)
])

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=
# array([[ 0.06153094, -0.16217081,  0.20170446, -0.15086699]],
#       dtype=float32)>

# %%
loss_fn= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)

# %%
model.compile(optimizer=optimizer,loss=loss_fn,metrics=['accuracy'])

history= model.fit(X_train,y_train,validation_data=(X_test,y_test),
                   batch_size=BATCH_SIZE,
                   epochs=EPOCHS,
                   verbose=2)
# Out:
# Epoch 1/101
# WARNING:tensorflow:From D:\Anaconda\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\Anaconda\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 57/57 - 4s - loss: 1.1088 - accuracy: 0.4743 - val_loss: 1.0415 - val_accuracy: 0.5416 - 4s/epoch - 72ms/step
# Epoch 2/101
# 57/57 - 0s - loss: 0.8464 - accuracy: 0.6488 - val_loss: 0.8965 - val_accuracy: 0.6975 - 328ms/epoch - 6ms/step
# Epoch 3/101
# 57/57 - 0s - loss: 0.7129 - accuracy: 0.8149 - val_loss: 0.7384 - val_accuracy: 0.8336 - 365ms/epoch - 6ms/step
# Epoch 4/101
# 57/57 - 0s - loss: 0.6071 - accuracy: 0.8590 - val_loss: 0.6108 - val_accuracy: 0.8532 - 363ms/epoch - 6ms/step
# Epoch 5/101
# 57/57 - 0s - loss: 0.5225 - accuracy: 0.8682 - val_loss: 0.5125 - val_accuracy: 0.8617 - 347ms/epoch - 6ms/step
# Epoch 6/101
# 57/57 - 0s - loss: 0.4613 - accuracy: 0.8699 - val_loss: 0.4537 - val_accuracy: 0.8612 - 344ms/epoch - 6ms/step
# Epoch 7/101
# 57/57 - 0s - loss: 0.4143 - accuracy: 0.8739 - val_loss: 0.4137 - val_accuracy: 0.8634 - 366ms/epoch - 6ms/step
# Epoch 8/101
# 57/57 - 0s - loss: 0.3847 - accuracy: 0.8777 - val_loss: 0.3847 - val_accuracy: 0.8658 - 320ms/epoch - 6ms/step
# Epoch 9/101
# 57/57 - 0s - loss: 0.3626 - accuracy: 0.8768 - val_loss: 0.3637 - val_accuracy: 0.8678 - 322ms/epoch - 6ms/step
# Epoch 10/101
# 57/57 - 0s - loss: 0.3453 - accuracy: 0.8797 - val_loss: 0.3496 - val_accuracy: 0.8705 - 351ms/epoch - 6ms/step
# Epoch 11/101
# 57/57 - 0s - loss: 0.3325 - accuracy: 0.8801 - val_loss: 0.3405 - val_accuracy: 0.8680 - 389ms/epoch - 7ms/step
# Epoch 12/101
# 57/57 - 0s - loss: 0.3233 - accuracy: 0.8797 - val_loss: 0.3319 - val_accuracy: 0.8730 - 364ms/epoch - 6ms/step
# Epoch 13/101
# 57/57 - 0s - loss: 0.3153 - accuracy: 0.8829 - val_loss: 0.3264 - val_accuracy: 0.8730 - 391ms/epoch - 7ms/step
# Epoch 14/101
# 57/57 - 0s - loss: 0.3104 - accuracy: 0.8814 - val_loss: 0.3231 - val_accuracy: 0.8708 - 368ms/epoch - 6ms/step
# Epoch 15/101
# 57/57 - 0s - loss: 0.3034 - accuracy: 0.8819 - val_loss: 0.3174 - val_accuracy: 0.8727 - 404ms/epoch - 7ms/step
# Epoch 16/101
# 57/57 - 0s - loss: 0.2980 - accuracy: 0.8817 - val_loss: 0.3155 - val_accuracy: 0.8736 - 388ms/epoch - 7ms/step
# Epoch 17/101
# 57/57 - 0s - loss: 0.2939 - accuracy: 0.8869 - val_loss: 0.3124 - val_accuracy: 0.8716 - 375ms/epoch - 7ms/step
# Epoch 18/101
# 57/57 - 0s - loss: 0.2926 - accuracy: 0.8862 - val_loss: 0.3122 - val_accuracy: 0.8763 - 375ms/epoch - 7ms/step
# Epoch 19/101
# 57/57 - 0s - loss: 0.2867 - accuracy: 0.8862 - val_loss: 0.3086 - val_accuracy: 0.8736 - 361ms/epoch - 6ms/step
# Epoch 20/101
# 57/57 - 0s - loss: 0.2838 - accuracy: 0.8872 - val_loss: 0.3089 - val_accuracy: 0.8736 - 390ms/epoch - 7ms/step
# Epoch 21/101
# 57/57 - 0s - loss: 0.2844 - accuracy: 0.8870 - val_loss: 0.3111 - val_accuracy: 0.8716 - 420ms/epoch - 7ms/step
# Epoch 22/101
# 57/57 - 0s - loss: 0.2791 - accuracy: 0.8887 - val_loss: 0.3108 - val_accuracy: 0.8711 - 341ms/epoch - 6ms/step
# Epoch 23/101
# 57/57 - 0s - loss: 0.2778 - accuracy: 0.8891 - val_loss: 0.3078 - val_accuracy: 0.8689 - 386ms/epoch - 7ms/step
# Epoch 24/101
# 57/57 - 0s - loss: 0.2747 - accuracy: 0.8905 - val_loss: 0.3085 - val_accuracy: 0.8680 - 386ms/epoch - 7ms/step
# Epoch 25/101
# 57/57 - 0s - loss: 0.2748 - accuracy: 0.8903 - val_loss: 0.3065 - val_accuracy: 0.8711 - 371ms/epoch - 7ms/step
# Epoch 26/101
# 57/57 - 0s - loss: 0.2712 - accuracy: 0.8893 - val_loss: 0.3067 - val_accuracy: 0.8694 - 371ms/epoch - 7ms/step
# Epoch 27/101
# 57/57 - 0s - loss: 0.2726 - accuracy: 0.8887 - val_loss: 0.3058 - val_accuracy: 0.8711 - 365ms/epoch - 6ms/step
# Epoch 28/101
# 57/57 - 0s - loss: 0.2676 - accuracy: 0.8919 - val_loss: 0.3094 - val_accuracy: 0.8675 - 416ms/epoch - 7ms/step
# Epoch 29/101
# 57/57 - 0s - loss: 0.2687 - accuracy: 0.8893 - val_loss: 0.3097 - val_accuracy: 0.8727 - 372ms/epoch - 7ms/step
# Epoch 30/101
# 57/57 - 0s - loss: 0.2667 - accuracy: 0.8945 - val_loss: 0.3089 - val_accuracy: 0.8716 - 380ms/epoch - 7ms/step
# Epoch 31/101
# 57/57 - 0s - loss: 0.2645 - accuracy: 0.8930 - val_loss: 0.3063 - val_accuracy: 0.8741 - 351ms/epoch - 6ms/step
# Epoch 32/101
# 57/57 - 0s - loss: 0.2634 - accuracy: 0.8917 - val_loss: 0.3103 - val_accuracy: 0.8733 - 367ms/epoch - 6ms/step
# Epoch 33/101
# 57/57 - 0s - loss: 0.2599 - accuracy: 0.8958 - val_loss: 0.3093 - val_accuracy: 0.8725 - 400ms/epoch - 7ms/step
# Epoch 34/101
# 57/57 - 0s - loss: 0.2612 - accuracy: 0.8947 - val_loss: 0.3068 - val_accuracy: 0.8736 - 355ms/epoch - 6ms/step
# Epoch 35/101
# 57/57 - 0s - loss: 0.2572 - accuracy: 0.8961 - val_loss: 0.3111 - val_accuracy: 0.8725 - 338ms/epoch - 6ms/step
# Epoch 36/101
# 57/57 - 0s - loss: 0.2597 - accuracy: 0.8938 - val_loss: 0.3103 - val_accuracy: 0.8744 - 362ms/epoch - 6ms/step
# Epoch 37/101
# 57/57 - 0s - loss: 0.2576 - accuracy: 0.8969 - val_loss: 0.3106 - val_accuracy: 0.8719 - 414ms/epoch - 7ms/step
# Epoch 38/101
# 57/57 - 0s - loss: 0.2569 - accuracy: 0.8954 - val_loss: 0.3132 - val_accuracy: 0.8689 - 406ms/epoch - 7ms/step
# Epoch 39/101
# 57/57 - 0s - loss: 0.2580 - accuracy: 0.8952 - val_loss: 0.3118 - val_accuracy: 0.8697 - 389ms/epoch - 7ms/step
# Epoch 40/101
# 57/57 - 0s - loss: 0.2548 - accuracy: 0.8989 - val_loss: 0.3121 - val_accuracy: 0.8705 - 402ms/epoch - 7ms/step
# Epoch 41/101
# 57/57 - 0s - loss: 0.2536 - accuracy: 0.8977 - val_loss: 0.3114 - val_accuracy: 0.8705 - 371ms/epoch - 7ms/step
# Epoch 42/101
# 57/57 - 0s - loss: 0.2531 - accuracy: 0.8981 - val_loss: 0.3154 - val_accuracy: 0.8689 - 391ms/epoch - 7ms/step
# Epoch 43/101
# 57/57 - 0s - loss: 0.2521 - accuracy: 0.8977 - val_loss: 0.3144 - val_accuracy: 0.8716 - 379ms/epoch - 7ms/step
# Epoch 44/101
# 57/57 - 0s - loss: 0.2526 - accuracy: 0.8971 - val_loss: 0.3120 - val_accuracy: 0.8708 - 347ms/epoch - 6ms/step
# Epoch 45/101
# 57/57 - 0s - loss: 0.2519 - accuracy: 0.8986 - val_loss: 0.3165 - val_accuracy: 0.8683 - 344ms/epoch - 6ms/step
# Epoch 46/101
# 57/57 - 0s - loss: 0.2478 - accuracy: 0.8998 - val_loss: 0.3121 - val_accuracy: 0.8705 - 323ms/epoch - 6ms/step
# Epoch 47/101
# 57/57 - 0s - loss: 0.2471 - accuracy: 0.8985 - val_loss: 0.3150 - val_accuracy: 0.8727 - 325ms/epoch - 6ms/step
# Epoch 48/101
# 57/57 - 0s - loss: 0.2472 - accuracy: 0.9011 - val_loss: 0.3131 - val_accuracy: 0.8736 - 412ms/epoch - 7ms/step
# Epoch 49/101
# 57/57 - 0s - loss: 0.2471 - accuracy: 0.9001 - val_loss: 0.3178 - val_accuracy: 0.8702 - 362ms/epoch - 6ms/step
# Epoch 50/101
# 57/57 - 0s - loss: 0.2460 - accuracy: 0.8977 - val_loss: 0.3164 - val_accuracy: 0.8716 - 306ms/epoch - 5ms/step
# Epoch 51/101
# 57/57 - 0s - loss: 0.2475 - accuracy: 0.8995 - val_loss: 0.3170 - val_accuracy: 0.8733 - 353ms/epoch - 6ms/step
# Epoch 52/101
# 57/57 - 0s - loss: 0.2412 - accuracy: 0.9022 - val_loss: 0.3169 - val_accuracy: 0.8733 - 396ms/epoch - 7ms/step
# Epoch 53/101
# 57/57 - 0s - loss: 0.2448 - accuracy: 0.8996 - val_loss: 0.3203 - val_accuracy: 0.8689 - 394ms/epoch - 7ms/step
# Epoch 54/101
# 57/57 - 0s - loss: 0.2412 - accuracy: 0.9024 - val_loss: 0.3193 - val_accuracy: 0.8691 - 394ms/epoch - 7ms/step
# Epoch 55/101
# 57/57 - 0s - loss: 0.2413 - accuracy: 0.9007 - val_loss: 0.3222 - val_accuracy: 0.8700 - 356ms/epoch - 6ms/step
# Epoch 56/101
# 57/57 - 0s - loss: 0.2416 - accuracy: 0.9015 - val_loss: 0.3246 - val_accuracy: 0.8675 - 372ms/epoch - 7ms/step
# Epoch 57/101
# 57/57 - 0s - loss: 0.2411 - accuracy: 0.9015 - val_loss: 0.3236 - val_accuracy: 0.8716 - 359ms/epoch - 6ms/step
# Epoch 58/101
# 57/57 - 0s - loss: 0.2404 - accuracy: 0.9026 - val_loss: 0.3264 - val_accuracy: 0.8656 - 345ms/epoch - 6ms/step
# Epoch 59/101
# 57/57 - 0s - loss: 0.2376 - accuracy: 0.9047 - val_loss: 0.3256 - val_accuracy: 0.8689 - 347ms/epoch - 6ms/step
# Epoch 60/101
# 57/57 - 0s - loss: 0.2416 - accuracy: 0.9008 - val_loss: 0.3301 - val_accuracy: 0.8639 - 371ms/epoch - 7ms/step
# Epoch 61/101
# 57/57 - 0s - loss: 0.2400 - accuracy: 0.9031 - val_loss: 0.3301 - val_accuracy: 0.8705 - 390ms/epoch - 7ms/step
# Epoch 62/101
# 57/57 - 0s - loss: 0.2368 - accuracy: 0.9035 - val_loss: 0.3325 - val_accuracy: 0.8669 - 389ms/epoch - 7ms/step
# Epoch 63/101
# 57/57 - 0s - loss: 0.2365 - accuracy: 0.9049 - val_loss: 0.3300 - val_accuracy: 0.8669 - 401ms/epoch - 7ms/step
# Epoch 64/101
# 57/57 - 0s - loss: 0.2349 - accuracy: 0.9041 - val_loss: 0.3353 - val_accuracy: 0.8620 - 357ms/epoch - 6ms/step
# Epoch 65/101
# 57/57 - 0s - loss: 0.2333 - accuracy: 0.9031 - val_loss: 0.3321 - val_accuracy: 0.8645 - 361ms/epoch - 6ms/step
# Epoch 66/101
# 57/57 - 0s - loss: 0.2377 - accuracy: 0.9041 - val_loss: 0.3295 - val_accuracy: 0.8667 - 354ms/epoch - 6ms/step
# Epoch 67/101
# 57/57 - 0s - loss: 0.2317 - accuracy: 0.9063 - val_loss: 0.3282 - val_accuracy: 0.8653 - 381ms/epoch - 7ms/step
# Epoch 68/101
# 57/57 - 0s - loss: 0.2323 - accuracy: 0.9061 - val_loss: 0.3283 - val_accuracy: 0.8636 - 364ms/epoch - 6ms/step
# Epoch 69/101
# 57/57 - 0s - loss: 0.2338 - accuracy: 0.9050 - val_loss: 0.3334 - val_accuracy: 0.8590 - 375ms/epoch - 7ms/step
# Epoch 70/101
# 57/57 - 0s - loss: 0.2298 - accuracy: 0.9065 - val_loss: 0.3343 - val_accuracy: 0.8661 - 385ms/epoch - 7ms/step
# Epoch 71/101
# 57/57 - 0s - loss: 0.2329 - accuracy: 0.9045 - val_loss: 0.3358 - val_accuracy: 0.8650 - 373ms/epoch - 7ms/step
# Epoch 72/101
# 57/57 - 0s - loss: 0.2303 - accuracy: 0.9057 - val_loss: 0.3342 - val_accuracy: 0.8656 - 349ms/epoch - 6ms/step
# Epoch 73/101
# 57/57 - 0s - loss: 0.2301 - accuracy: 0.9081 - val_loss: 0.3384 - val_accuracy: 0.8628 - 358ms/epoch - 6ms/step
# Epoch 74/101
# 57/57 - 0s - loss: 0.2285 - accuracy: 0.9058 - val_loss: 0.3365 - val_accuracy: 0.8628 - 394ms/epoch - 7ms/step
# Epoch 75/101
# 57/57 - 0s - loss: 0.2290 - accuracy: 0.9064 - val_loss: 0.3381 - val_accuracy: 0.8609 - 367ms/epoch - 6ms/step
# Epoch 76/101
# 57/57 - 0s - loss: 0.2298 - accuracy: 0.9054 - val_loss: 0.3400 - val_accuracy: 0.8664 - 361ms/epoch - 6ms/step
# Epoch 77/101
# 57/57 - 0s - loss: 0.2299 - accuracy: 0.9060 - val_loss: 0.3431 - val_accuracy: 0.8603 - 367ms/epoch - 6ms/step
# Epoch 78/101
# 57/57 - 0s - loss: 0.2260 - accuracy: 0.9069 - val_loss: 0.3403 - val_accuracy: 0.8634 - 384ms/epoch - 7ms/step
# Epoch 79/101
# 57/57 - 0s - loss: 0.2256 - accuracy: 0.9085 - val_loss: 0.3428 - val_accuracy: 0.8587 - 359ms/epoch - 6ms/step
# Epoch 80/101
# 57/57 - 0s - loss: 0.2266 - accuracy: 0.9062 - val_loss: 0.3418 - val_accuracy: 0.8612 - 383ms/epoch - 7ms/step
# Epoch 81/101
# 57/57 - 0s - loss: 0.2269 - accuracy: 0.9071 - val_loss: 0.3414 - val_accuracy: 0.8645 - 382ms/epoch - 7ms/step
# Epoch 82/101
# 57/57 - 0s - loss: 0.2254 - accuracy: 0.9082 - val_loss: 0.3448 - val_accuracy: 0.8592 - 405ms/epoch - 7ms/step
# Epoch 83/101
# 57/57 - 0s - loss: 0.2239 - accuracy: 0.9084 - val_loss: 0.3433 - val_accuracy: 0.8645 - 363ms/epoch - 6ms/step
# Epoch 84/101
# 57/57 - 0s - loss: 0.2288 - accuracy: 0.9072 - val_loss: 0.3441 - val_accuracy: 0.8661 - 419ms/epoch - 7ms/step
# Epoch 85/101
# 57/57 - 0s - loss: 0.2250 - accuracy: 0.9080 - val_loss: 0.3450 - val_accuracy: 0.8625 - 377ms/epoch - 7ms/step
# Epoch 86/101
# 57/57 - 0s - loss: 0.2244 - accuracy: 0.9084 - val_loss: 0.3452 - val_accuracy: 0.8639 - 367ms/epoch - 6ms/step
# Epoch 87/101
# 57/57 - 0s - loss: 0.2190 - accuracy: 0.9093 - val_loss: 0.3449 - val_accuracy: 0.8669 - 382ms/epoch - 7ms/step
# Epoch 88/101
# 57/57 - 0s - loss: 0.2252 - accuracy: 0.9095 - val_loss: 0.3470 - val_accuracy: 0.8653 - 351ms/epoch - 6ms/step
# Epoch 89/101
# 57/57 - 0s - loss: 0.2228 - accuracy: 0.9100 - val_loss: 0.3457 - val_accuracy: 0.8631 - 360ms/epoch - 6ms/step
# Epoch 90/101
# 57/57 - 0s - loss: 0.2192 - accuracy: 0.9116 - val_loss: 0.3504 - val_accuracy: 0.8592 - 369ms/epoch - 6ms/step
# Epoch 91/101
# 57/57 - 0s - loss: 0.2213 - accuracy: 0.9089 - val_loss: 0.3522 - val_accuracy: 0.8592 - 402ms/epoch - 7ms/step
# Epoch 92/101
# 57/57 - 0s - loss: 0.2214 - accuracy: 0.9115 - val_loss: 0.3477 - val_accuracy: 0.8617 - 334ms/epoch - 6ms/step
# Epoch 93/101
# 57/57 - 0s - loss: 0.2198 - accuracy: 0.9099 - val_loss: 0.3498 - val_accuracy: 0.8631 - 371ms/epoch - 7ms/step
# Epoch 94/101
# 57/57 - 0s - loss: 0.2193 - accuracy: 0.9096 - val_loss: 0.3495 - val_accuracy: 0.8612 - 336ms/epoch - 6ms/step
# Epoch 95/101
# 57/57 - 0s - loss: 0.2199 - accuracy: 0.9113 - val_loss: 0.3514 - val_accuracy: 0.8653 - 389ms/epoch - 7ms/step
# Epoch 96/101
# 57/57 - 0s - loss: 0.2211 - accuracy: 0.9095 - val_loss: 0.3529 - val_accuracy: 0.8634 - 348ms/epoch - 6ms/step
# Epoch 97/101
# 57/57 - 0s - loss: 0.2176 - accuracy: 0.9120 - val_loss: 0.3599 - val_accuracy: 0.8598 - 385ms/epoch - 7ms/step
# Epoch 98/101
# 57/57 - 0s - loss: 0.2155 - accuracy: 0.9144 - val_loss: 0.3600 - val_accuracy: 0.8579 - 366ms/epoch - 6ms/step
# Epoch 99/101
# 57/57 - 0s - loss: 0.2218 - accuracy: 0.9100 - val_loss: 0.3541 - val_accuracy: 0.8606 - 347ms/epoch - 6ms/step
# Epoch 100/101
# 57/57 - 0s - loss: 0.2198 - accuracy: 0.9089 - val_loss: 0.3590 - val_accuracy: 0.8645 - 387ms/epoch - 7ms/step
# Epoch 101/101
# 57/57 - 0s - loss: 0.2151 - accuracy: 0.9127 - val_loss: 0.3616 - val_accuracy: 0.8584 - 373ms/epoch - 7ms/step

# %%
fn_plot_tf_hist(pd.DataFrame(history.history))
